# %%
import warnings
warnings.filterwarnings("ignore")

import osmnx as ox
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

city_data_vault = {}

def calculate_orientation_entropy(bearings, num_bins=36):
    if not bearings:
        return 0.0
    bins = np.arange(0, 360 + 360 / num_bins, 360 / num_bins)
    counts, _ = np.histogram(bearings, bins=bins)
    prob = counts / counts.sum()
    prob = prob[prob > 0]
    entropy = -np.sum(prob * np.log(prob))
    return entropy

def generate_styled_map(zone_id, coords, label, dist=3000):
    G = ox.graph_from_point(coords, dist=dist, network_type='drive')
    G_proj = ox.project_graph(G)
    
    fig, ax = ox.plot_graph(G_proj, 
                            node_size=5,          
                            node_color='#FF8C00', 
                            edge_color='white',   
                            edge_linewidth=0.6,   
                            bgcolor='black',      
                            show=True, 
                            close=False)
    
    G = ox.add_edge_bearings(G)
    bearings = [d['bearing'] for u, v, k, d in G.edges(keys=True, data=True) if 'bearing' in d]
    entropy_val = calculate_orientation_entropy(bearings)
    
    fig_rose, ax_rose = ox.plot_orientation(G, 
                                            num_bins=36, 
                                            figsize=(5, 5),
                                            color='#003366',    
                                            edgecolor='k',      
                                            linewidth=0.5)
    plt.show()
    
    nodes_gdf, edges_gdf = ox.graph_to_gdfs(G_proj)
    stats = ox.basic_stats(G_proj)
    
    try:
        area_km2 = nodes_gdf.union_all().convex_hull.area / 1_000_000
    except AttributeError:
        area_km2 = nodes_gdf.unary_union.convex_hull.area / 1_000_000
        
    intersections = len([n for n, deg in G_proj.degree() if deg > 2])
    intersection_density = intersections / area_km2 if area_km2 > 0 else 0
    
    centrality_dict = nx.degree_centrality(G_proj)
    avg_centrality = np.mean(list(centrality_dict.values()))

    city_data_vault[label] = {
        'bearings': bearings,
        'orientation_entropy': entropy_val,
        'avg_area': area_km2,  
        'intersection_density': intersection_density,  
        'avg_edge_length': stats.get('street_length_avg', 0),  
        'avg_circuity': stats.get('circuity_avg', 0), 
        'avg_degree_centrality': avg_centrality 
    }

# %%
generate_styled_map("01", (37.873, 112.548), "Yingze (City Core)", dist=2500)           # 迎泽市中心

# %%
generate_styled_map("02", (37.885, 112.565), "Xinghualing (Old Town)", dist=2500)       # 杏花岭老城区

# %%
generate_styled_map("03", (37.870, 112.515), "Wanblin (West Bank Core)", dist=2500)     # 万柏林河西核心

# %%
generate_styled_map("04", (37.835, 112.550), "Xiaodian (South CBD)", dist=2500)        # 小店南部CBD

# %%
generate_styled_map("05", (37.915, 112.540), "Jiancaoping (North Area)", dist=3000)    # 尖草坪北部片区

# %%
generate_styled_map("06", (37.805, 112.485), "Jinyuan (Jinyang Lake)", dist=3000)       # 晋源晋阳湖片区

# %%
generate_styled_map("07", (37.840, 112.590), "Taiyuan South Station", dist=2500)       # 太原南站

# %%
generate_styled_map("08", (37.855, 112.530), "Changfeng Business District", dist=2500)  # 长风商务区

# %%
generate_styled_map("09", (37.825, 112.610), "Wusu Airport Area", dist=3000)           # 武宿机场片区

# %%
generate_styled_map("10", (37.890, 112.495), "West Mountain Ecological Zone", dist=3000)# 西山生态区

# %%
generate_styled_map("11", (37.900, 112.580), "North New City", dist=3000)              # 北部新城

# %%
generate_styled_map("12", (37.815, 112.535), "South New City", dist=3000)             # 南部新城

# %%
print("\n" + "="*70)
print("TAIYUAN CITY MORPHOLOGY: QUANTITATIVE SUMMARY")
print("="*70)

for label, d in city_data_vault.items():
    print(f"\n>> {label.upper()}")
    
    area = d.get('avg_area', 0)
    density = d.get('intersection_density', 0)
    nodes = d.get('nodes', 0)
    avg_degree = d.get('avg_degree', 0) 
    avg_length = d.get('avg_edge_length', 0)
    circuity = d.get('avg_circuity', 0)
    entropy = d.get('orientation_entropy', 0)
    centrality = d.get('avg_degree_centrality', 0)

    print(f"   Scale: {area:.2f} sq km | {nodes} nodes")
    print(f"   Connectivity: {density:.2f} int/km² | Centrality: {centrality:.4f}")
    print(f"   Complexity: {avg_length:.1f}m avg length | {circuity:.3f} circuity")
    
    if entropy < 3.0:
        morph = "Regular"
    elif entropy < 3.4:
        morph = "Semi-Regular"
    else:
        morph = "complex"
        
    print(f"   Orientation Entropy: {entropy:.4f} ({morph})")
# Out:
# ======================================================================
# TAIYUAN CITY MORPHOLOGY: QUANTITATIVE SUMMARY
# ======================================================================
#
# >> YINGZE (CITY CORE)
#    Scale: 24.03 sq km | 0 nodes
#    Connectivity: 52.31 int/km² | Centrality: 0.0027
#    Complexity: 144.7m avg length | 1.036 circuity
#    Orientation Entropy: 2.7161 (Regular)
#
# >> XINGHUALING (OLD TOWN)
#    Scale: 23.86 sq km | 0 nodes
#    Connectivity: 52.43 int/km² | Centrality: 0.0026
#    Complexity: 142.2m avg length | 1.025 circuity
#    Orientation Entropy: 2.8191 (Regular)
#
# >> WANBLIN (WEST BANK CORE)
#    Scale: 24.10 sq km | 0 nodes
#    Connectivity: 36.35 int/km² | Centrality: 0.0042
#    Complexity: 174.1m avg length | 1.037 circuity
#    Orientation Entropy: 2.5749 (Regular)
#
# >> XIAODIAN (SOUTH CBD)
#    Scale: 23.93 sq km | 0 nodes
#    Connectivity: 33.30 int/km² | Centrality: 0.0044
#    Complexity: 189.9m avg length | 1.055 circuity
#    Orientation Entropy: 2.7337 (Regular)
#
# >> JIANCAOPING (NORTH AREA)
#    Scale: 34.69 sq km | 0 nodes
#    Connectivity: 29.72 int/km² | Centrality: 0.0030
#    Complexity: 184.5m avg length | 1.049 circuity
#    Orientation Entropy: 3.2359 (Semi-Regular)
#
# >> JINYUAN (JINYANG LAKE)
#    Scale: 33.05 sq km | 0 nodes
#    Connectivity: 14.34 int/km² | Centrality: 0.0073
#    Complexity: 258.2m avg length | 1.059 circuity
#    Orientation Entropy: 2.8945 (Regular)
#
# >> TAIYUAN SOUTH STATION
#    Scale: 23.41 sq km | 0 nodes
#    Connectivity: 25.25 int/km² | Centrality: 0.0057
#    Complexity: 214.4m avg length | 1.037 circuity
#    Orientation Entropy: 2.8007 (Regular)
#
# >> CHANGFENG BUSINESS DISTRICT
#    Scale: 24.05 sq km | 0 nodes
#    Connectivity: 38.93 int/km² | Centrality: 0.0037
#    Complexity: 170.0m avg length | 1.041 circuity
#    Orientation Entropy: 2.6563 (Regular)
#
# >> WUSU AIRPORT AREA
#    Scale: 32.90 sq km | 0 nodes
#    Connectivity: 17.18 int/km² | Centrality: 0.0057
#    Complexity: 238.3m avg length | 1.053 circuity
#    Orientation Entropy: 3.0060 (Semi-Regular)
#
# >> WEST MOUNTAIN ECOLOGICAL ZONE
#    Scale: 31.48 sq km | 0 nodes
#    Connectivity: 25.35 int/km² | Centrality: 0.0045
#    Complexity: 206.1m avg length | 1.045 circuity
#    Orientation Entropy: 2.8278 (Regular)
#
# >> NORTH NEW CITY
#    Scale: 34.57 sq km | 0 nodes
#    Connectivity: 36.39 int/km² | Centrality: 0.0026
#    Complexity: 170.6m avg length | 1.045 circuity
#    Orientation Entropy: 3.0835 (Semi-Regular)
#
# >> SOUTH NEW CITY
#    Scale: 35.52 sq km | 0 nodes
#    Connectivity: 30.46 int/km² | Centrality: 0.0033
#    Complexity: 200.5m avg length | 1.041 circuity
#    Orientation Entropy: 2.9158 (Regular)

# %%
all_combined_bearings = []
collected_labels = []

metrics = {
    'area': [],
    'entropy': [],
    'int_density': [],
    'edge_length': [],
    'circuity': [],
    'centrality': []
}

for label, data in city_data_vault.items():
    if 'bearings' in data and data['bearings'] is not None:
        all_combined_bearings.extend(list(data['bearings']))
        collected_labels.append(label)
        
        metrics['area'].append(data.get('avg_area', 0))
        metrics['entropy'].append(data.get('orientation_entropy', 0))
        metrics['int_density'].append(data.get('intersection_density', 0))
        metrics['edge_length'].append(data.get('avg_edge_length', 0))
        metrics['circuity'].append(data.get('avg_circuity', 0))
        metrics['centrality'].append(data.get('avg_degree_centrality', 0))

if not all_combined_bearings:
    print("Error: No data collected from the dictionary.")
else:
    avg_metrics = {k: np.mean(v) for k, v in metrics.items()}
    
    n = 36
    bins = np.arange(0, 360 + 360/n, 360/n)
    counts, _ = np.histogram(all_combined_bearings, bins=bins)
    proportions = counts / counts.sum()

    fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'projection': 'polar'})
    ax.set_theta_zero_location('N')
    ax.set_theta_direction(-1)

    ax.bar(np.radians(bins[:-1]), proportions, width=np.radians(360/n), 
           color='#003366', edgecolor='black', linewidth=0.5)

    stats_text = (
        f"Taiyuan City Metrics\n"
        f"Avg Area: {avg_metrics['area']:.2f} | "
        f"Avg Entropy: {avg_metrics['entropy']:.4f}\n"
        f"Avg Int. Density: {avg_metrics['int_density']:.2f} | "
        f"Avg Edge Length: {avg_metrics['edge_length']:.2f}\n"
        f"Avg Circuity: {avg_metrics['circuity']:.4f} | "
        f"Avg Degree Centrality: {avg_metrics['centrality']:.4f}"
    )
    
    ax.set_title(stats_text, pad=30, fontsize=10)
    plt.show()
